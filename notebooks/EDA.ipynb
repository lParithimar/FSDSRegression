# %%
#data ingestion step
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/krishnaik06/FSDSRegression/main/notebooks/data/gemstone.csv")

# %%
df
# Out:
#             id  carat        cut color clarity  depth  table     x     y
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  \
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# ...

# %%
df_copy=df.head(10000)

# %%
df_copy
# Out:
#         id  carat        cut color clarity  depth  table     x     y     z
# 0        0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  \
# 1        1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...    ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 9995  9995   0.31    Premium     I     VS1   61.1   60.0  4.35  4.32  2.66
# 9996  9996   2.20    Premium     J     SI2   62.6   59.0  8.31  8.25  5.18
# 9997  9997   2.05    Premium     D     SI2   58.8   59.0  8.32  8.26  4.93
# 9998  9998   0.71      Ideal     E    VVS2   61.0   56.0  5.74  5.77  3.51
# 9999  9999   1.02      Ideal     F     VS2   61.8   57.0  6.42  6.46  3.99
#
#       price
# 0     13619
# 1     13387
# 2      2772
# 3       666
# ...

# %%
import pandas as pd

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
##No missing values in the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
#cut,color, clarity are object variables so we have to change those 
#into numerical values using encoding techniques like one hot encoding

# %%
#id column is unique and uncessary column so drop it

#unique values for example  roll no, aathar card no won't be usefull in prediction so drop it

df=df.drop(labels="id",axis=1)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
#check for duplicated records
df.duplicated().sum()
# Out:
# 0

# %%
# df.drop_duplicates() to drop the duplicates. sinc there is no duplicates here we did not use it

# %%
numerical_columns=df.columns[df.dtypes!="object"]
categorical_columns=df.columns[df.dtypes=='object']

# %%
print("numerical_columns",numerical_columns)
print("categorical_columns",categorical_columns)
# Out:
# numerical_columns Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# categorical_columns Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))

for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print("\n")
    plt.show()

# %%
for i in categorical_columns:
    sns.countplot(data=df,x=i)
    print("\n")
    plt.show()

# %%
#correlation

sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
#x,y,z and carat independent features are highlyl correelated so we can drop x,y,z because carat is
# highly correlated with (price) dependent feature than that of x,y,z. but we do not drop it here 
#because we have to know overfitting

# %%
#just to know you have done pair plot with df_copy data frame since it will take too much time for your one lakh record
#you have used df_copy
sns.pairplot(df_copy)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
#cut is a ordinal feature 
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map={"I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map={"D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7}

# %%
df['cut']=df['cut'].replace(cut_map)
df['clarity']=df['clarity'].map(clarity_map)
df['color']=df['color'].replace(color_map)

# %%
df.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
